# %% [markdown]
# <a href="https://colab.research.google.com/github/wikistat/High-Dimensional-Deep-Learning/blob/master/AutoEncoder/VariationalAutoEncoder_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <a href="http://www.insa-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo-insa.jpg" style="float:left; max-width: 120px; display: inline" alt="INSA"/></a>
# <a href="http://wikistat.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/wikistat.jpg" style="max-width: 150px; display: inline"  alt="Wikistat"/></a>
# <a href="http://www.math.univ-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo_imt.jpg" width=400,  style="float:right;  display: inline" alt="IMT"/> </a>
#
# </center>

# %% [markdown]
# # Files & Data (Google Colab)
#
# If you're running this notebook on Google colab, you do not have access to the `solutions` folder you get by cloning the repository locally.
#
# The following lines will allow you to build the folders and the files you need for this TP.
#
# **WARNING 1** Do not run this line localy.
# **WARNING 2** The magic command `%load` does not work work on google colab, you will have to copy-paste the solution on the notebook.

# %%
! mkdir image
! wget . https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_decoder.png
! wget . https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_vae.png
! wget image https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_2.svg
! wget image https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_3.svg
! mkdir solutions
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/convolutional_autoencoder.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoded_images_both_method.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoder_vae.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/generate_single_sample.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/simple_autoencoder.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/vae.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/train_outlier_vae.py
! wget solutions https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/error_distribution.py
# Out:
# mkdir: impossible de créer le répertoire «image»: Le fichier existe
# --2022-10-19 11:06:37--  http://./
# Résolution de . (.)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « . »
# --2022-10-19 11:06:37--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_decoder.png
# Résolution de github.com (github.com)… 140.82.121.4
# Connexion à github.com (github.com)|140.82.121.4|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_decoder.png [suivant]
# --2022-10-19 11:06:37--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_decoder.png
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 22573 (22K) [image/png]
# Sauvegarde en : « vae_mlp_decoder.png.4 »
#
# vae_mlp_decoder.png 100%[===================>]  22,04K  --.-KB/s    ds 0,002s
#
# 2022-10-19 11:06:37 (10,5 MB/s) — « vae_mlp_decoder.png.4 » sauvegardé [22573/22573]
#
# Terminé — 2022-10-19 11:06:37 —
# Temps total effectif : 0,3s
# Téléchargés : 1 fichiers, 22K en 0,002s (10,5 MB/s)
# --2022-10-19 11:06:37--  http://./
# Résolution de . (.)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « . »
# --2022-10-19 11:06:37--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/vae_mlp_vae.png
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_vae.png [suivant]
# --2022-10-19 11:06:40--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/vae_mlp_vae.png
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 21694 (21K) [image/png]
# Sauvegarde en : « vae_mlp_vae.png.4 »
#
# vae_mlp_vae.png.4   100%[===================>]  21,19K  --.-KB/s    ds 0,002s
#
# 2022-10-19 11:06:40 (12,0 MB/s) — « vae_mlp_vae.png.4 » sauvegardé [21694/21694]
#
# Terminé — 2022-10-19 11:06:40 —
# Temps total effectif : 2,4s
# Téléchargés : 1 fichiers, 21K en 0,002s (12,0 MB/s)
# --2022-10-19 11:06:40--  http://image/
# Résolution de image (image)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « image »
# --2022-10-19 11:06:40--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_2.svg
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_2.svg [suivant]
# --2022-10-19 11:06:49--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_2.svg
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 206667 (202K) [image/svg+xml]
# Sauvegarde en : « vae_2.svg.3 »
#
# vae_2.svg.3         100%[===================>] 201,82K  --.-KB/s    ds 0,08s
#
# 2022-10-19 11:06:49 (2,46 MB/s) — « vae_2.svg.3 » sauvegardé [206667/206667]
#
# Terminé — 2022-10-19 11:06:49 —
# Temps total effectif : 9,2s
# Téléchargés : 1 fichiers, 202K en 0,08s (2,46 MB/s)
# --2022-10-19 11:06:49--  http://image/
# Résolution de image (image)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « image »
# --2022-10-19 11:06:49--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/image/vae_3.svg
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_3.svg [suivant]
# --2022-10-19 11:06:50--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/image/vae_3.svg
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 452473 (442K) [image/svg+xml]
# Sauvegarde en : « vae_3.svg.3 »
#
# vae_3.svg.3         100%[===================>] 441,87K  2,86MB/s    ds 0,2s
#
# 2022-10-19 11:06:50 (2,86 MB/s) — « vae_3.svg.3 » sauvegardé [452473/452473]
#
# Terminé — 2022-10-19 11:06:50 —
# Temps total effectif : 1,0s
# Téléchargés : 1 fichiers, 442K en 0,2s (2,86 MB/s)
# mkdir: impossible de créer le répertoire «solutions»: Le fichier existe
# --2022-10-19 11:06:51--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:06:51--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py [suivant]
# --2022-10-19 11:06:51--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_decoded_imgs.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 799 [text/plain]
# Sauvegarde en : « compare_sparsity_decoded_imgs.py.3 »
#
# compare_sparsity_de 100%[===================>]     799  --.-KB/s    ds 0s
#
# 2022-10-19 11:06:51 (19,3 MB/s) — « compare_sparsity_decoded_imgs.py.3 » sauvegardé [799/799]
#
# Terminé — 2022-10-19 11:06:51 —
# Temps total effectif : 0,6s
# Téléchargés : 1 fichiers, 799 en 0s (19,3 MB/s)
# --2022-10-19 11:06:51--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:06:51--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py [suivant]
# --2022-10-19 11:06:55--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/compare_sparsity_encoded_imgs.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 455 [text/plain]
# Sauvegarde en : « compare_sparsity_encoded_imgs.py.3 »
#
# compare_sparsity_en 100%[===================>]     455  --.-KB/s    ds 0s
#
# 2022-10-19 11:06:55 (11,0 MB/s) — « compare_sparsity_encoded_imgs.py.3 » sauvegardé [455/455]
#
# Terminé — 2022-10-19 11:06:55 —
# Temps total effectif : 3,4s
# Téléchargés : 1 fichiers, 455 en 0s (11,0 MB/s)
# --2022-10-19 11:06:55--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:06:55--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/convolutional_autoencoder.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/convolutional_autoencoder.py [suivant]
# --2022-10-19 11:06:56--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/convolutional_autoencoder.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1063 (1,0K) [text/plain]
# Sauvegarde en : « convolutional_autoencoder.py.3 »
#
# convolutional_autoe 100%[===================>]   1,04K  --.-KB/s    ds 0s
#
# 2022-10-19 11:06:56 (32,5 MB/s) — « convolutional_autoencoder.py.3 » sauvegardé [1063/1063]
#
# Terminé — 2022-10-19 11:06:56 —
# Temps total effectif : 1,4s
# Téléchargés : 1 fichiers, 1,0K en 0s (32,5 MB/s)
# --2022-10-19 11:06:56--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:06:56--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoded_images_both_method.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoded_images_both_method.py [suivant]
# --2022-10-19 11:06:58--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoded_images_both_method.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1129 (1,1K) [text/plain]
# Sauvegarde en : « decoded_images_both_method.py.3 »
#
# decoded_images_both 100%[===================>]   1,10K  --.-KB/s    ds 0s
#
# 2022-10-19 11:06:58 (25,2 MB/s) — « decoded_images_both_method.py.3 » sauvegardé [1129/1129]
#
# Terminé — 2022-10-19 11:06:58 —
# Temps total effectif : 1,8s
# Téléchargés : 1 fichiers, 1,1K en 0s (25,2 MB/s)
# --2022-10-19 11:06:58--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:06:58--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/decoder_vae.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoder_vae.py [suivant]
# --2022-10-19 11:07:07--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/decoder_vae.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 292 [text/plain]
# Sauvegarde en : « decoder_vae.py.3 »
#
# decoder_vae.py.3    100%[===================>]     292  --.-KB/s    ds 0s
#
# 2022-10-19 11:07:07 (7,73 MB/s) — « decoder_vae.py.3 » sauvegardé [292/292]
#
# Terminé — 2022-10-19 11:07:07 —
# Temps total effectif : 9,1s
# Téléchargés : 1 fichiers, 292 en 0s (7,73 MB/s)
# --2022-10-19 11:07:08--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:07:08--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/generate_single_sample.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/generate_single_sample.py [suivant]
# --2022-10-19 11:07:11--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/generate_single_sample.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 141 [text/plain]
# Sauvegarde en : « generate_single_sample.py.3 »
#
# generate_single_sam 100%[===================>]     141  --.-KB/s    ds 0s
#
# 2022-10-19 11:07:11 (3,50 MB/s) — « generate_single_sample.py.3 » sauvegardé [141/141]
#
# Terminé — 2022-10-19 11:07:11 —
# Temps total effectif : 3,5s
# Téléchargés : 1 fichiers, 141 en 0s (3,50 MB/s)
# --2022-10-19 11:07:11--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:07:11--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/simple_autoencoder.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/simple_autoencoder.py [suivant]
# --2022-10-19 11:07:14--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/simple_autoencoder.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 260 [text/plain]
# Sauvegarde en : « simple_autoencoder.py.3 »
#
# simple_autoencoder. 100%[===================>]     260  --.-KB/s    ds 0s
#
# 2022-10-19 11:07:14 (7,03 MB/s) — « simple_autoencoder.py.3 » sauvegardé [260/260]
#
# Terminé — 2022-10-19 11:07:14 —
# Temps total effectif : 3,0s
# Téléchargés : 1 fichiers, 260 en 0s (7,03 MB/s)
# --2022-10-19 11:07:14--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:07:14--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/vae.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/vae.py [suivant]
# --2022-10-19 11:07:16--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/vae.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 120 [text/plain]
# Sauvegarde en : « vae.py.2 »
#
# vae.py.2            100%[===================>]     120  --.-KB/s    ds 0s
#
# 2022-10-19 11:07:16 (4,13 MB/s) — « vae.py.2 » sauvegardé [120/120]
#
# Terminé — 2022-10-19 11:07:16 —
# Temps total effectif : 2,0s
# Téléchargés : 1 fichiers, 120 en 0s (4,13 MB/s)
# --2022-10-19 11:07:17--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:07:17--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/train_outlier_vae.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/train_outlier_vae.py [suivant]
# --2022-10-19 11:07:20--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/train_outlier_vae.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 1122 (1,1K) [text/plain]
# Sauvegarde en : « train_outlier_vae.py.2 »
#
# train_outlier_vae.p 100%[===================>]   1,10K  --.-KB/s    ds 0s
#
# 2022-10-19 11:07:20 (27,0 MB/s) — « train_outlier_vae.py.2 » sauvegardé [1122/1122]
#
# Terminé — 2022-10-19 11:07:20 —
# Temps total effectif : 3,1s
# Téléchargés : 1 fichiers, 1,1K en 0s (27,0 MB/s)
# --2022-10-19 11:07:20--  http://solutions/
# Résolution de solutions (solutions)… échec : Échec temporaire dans la résolution du nom.
# wget : impossible de résoudre l’adresse de l’hôte « solutions »
# --2022-10-19 11:07:20--  https://github.com/wikistat/High-Dimensional-Deep-Learning/raw/master/AutoEncoder/solutions/error_distribution.py
# Résolution de github.com (github.com)… 140.82.121.3
# Connexion à github.com (github.com)|140.82.121.3|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 302 Found
# Emplacement : https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/error_distribution.py [suivant]
# --2022-10-19 11:07:23--  https://raw.githubusercontent.com/wikistat/High-Dimensional-Deep-Learning/master/AutoEncoder/solutions/error_distribution.py
# Résolution de raw.githubusercontent.com (raw.githubusercontent.com)… 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connexion à raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 515 [text/plain]
# Sauvegarde en : « error_distribution.py.2 »
#
# error_distribution. 100%[===================>]     515  --.-KB/s    ds 0s
#
# 2022-10-19 11:07:23 (12,1 MB/s) — « error_distribution.py.2 » sauvegardé [515/515]
#
# Terminé — 2022-10-19 11:07:23 —
# Temps total effectif : 3,3s
# Téléchargés : 1 fichiers, 515 en 0s (12,1 MB/s)

# %% [markdown]
# # High Dimensional & Deep Learning : Variational Autoencoders

# %% [markdown]
# ## What is a Variational Autoencoder

# %% [markdown]
# A variational autoencoder is an autoencoder that learns a latent variable model for its input data.

# %% [markdown]
# ## Objective

# %% [markdown]
# * Build a simple Variational Auto Encoder
# * Use Variational Auto Encoder for Number Generation
# * Use Variational Auto Encoder To anomaly detection
# * Write a Convolutional Variational Auto Encoder
# * Use the Keras Model APi

# %% [markdown]
# ## Library

# %%
from tensorflow.keras.datasets import mnist
import tensorflow.keras.preprocessing.image as kpi
import tensorflow.keras.models as km
import tensorflow.keras.layers as kl
import tensorflow.keras.losses as kloss
import tensorflow.keras.regularizers as kr
import tensorflow.keras.backend as K
import tensorflow.keras.utils as ku

import numpy as np
import scipy as sc

import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style("whitegrid")
# Out:
# 2022-10-19 11:07:24.054543: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ## Data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
input_dim = np.prod(x_train.shape[1:])
n_train = x_train.shape[0]
n_test = x_test.shape[0]
x_train = x_train.reshape((n_train, input_dim))
x_test = x_test.reshape((n_test, input_dim))

# %% [markdown]
# ## Keras Model API

# %% [markdown]
# In the previous TP on image classification of the autoencoder notebook we have used the `Sequential` method to build model.
#
# Sequential Method have limits when the architecture we want is not *linear* or when we want to build a layer on top on two different entries.
#
# The `Model` API can sometimes be less intuitive but is much more flexible than the `Sequential` method. We will use it all along this TP.

# %% [markdown]
# ## A simple Variational Autoencoders

# %% [markdown]
# ### Param

# %%
# network parameters
n_input = 784
batch_size=100
intermediate_dim = 512
latent_dim = 2
epochs = 25

# %% [markdown]
# ### Encoder

# %% [markdown]
# #### Latent Variable

# %% [markdown]
# We first build the encoder part. <br>
# It is first composed of  a `Dense` layer with 512 neurons. <br>
# Two `Dense` layers are then added on **top of the same layer**. These two layers will produce the two variables *z_mean* and  *z_log_var* in the latent space.
#
# Note that we define each layer as a function of an input which is the output of the layer it follows.

# %%
# Input layer
inputs = kl.Input(shape=(784,), name='encoder_input')
# Dense layer from input layer
x = kl.Dense(intermediate_dim, activation='relu')(inputs)
# Two dense layer that takes input from the same layer x
z_mean = kl.Dense(latent_dim, name='z_mean')(x)
z_log_var = kl.Dense(latent_dim, name='z_log_var')(x)
# Out:
# 2022-10-19 11:07:30.697535: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-19 11:07:30.698633: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-10-19 11:07:30.759256: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-10-19 11:07:30.759315: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:07:30.766518: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-19 11:07:30.766657: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-10-19 11:07:30.768760: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:07:30.769375: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:07:30.773096: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:07:30.774769: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-19 11:07:30.775132: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-19 11:07:30.777225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-19 11:07:30.777802: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-19 11:07:30.778102: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-19 11:07:30.779102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-10-19 11:07:30.779128: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:07:30.779159: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-10-19 11:07:30.779175: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-10-19 11:07:30.779190: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-19 11:07:30.779206: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-19 11:07:30.779221: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-19 11:07:30.779236: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-10-19 11:07:30.779252: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-10-19 11:07:30.780833: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-19 11:07:30.780876: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-19 11:07:31.336742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-19 11:07:31.336774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-10-19 11:07:31.336783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-10-19 11:07:31.338301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10020 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:65:00.0, compute capability: 6.1)

# %% [markdown]
# ### The stochastic latent variable
#
# We use the reparametrization trick to define a random variable z that is conditioned on the input image x as follows:
#
# $$ q(z/x) \sim \mathcal{N}(\mu_z(x), \sigma_z(x)) $$
#
# <img src="image/vae_3.svg" width="600px" />
#
#
#
# The reparametrization tricks defines $z$ has follows:
#
# $$ q(z/x) = \mu_z(x) + \sigma_z(x) \cdot \epsilon$$
#
# with:
#
# $$ \epsilon \sim \mathcal{N}(0, 1) $$
#
# This way the dependency to between $z$ and $x$ is deterministic and differentiable. The randomness of $z$ only stems from $\epsilon$ only for a given $x$.
#
# Note that in practice the output of the encoder network parameterizes $log(\sigma^2_z(x))$ instead of $\sigma_z(x)$. <br>
# Taking the exponential of $log(\sigma^2_z(x)$ ensures the positivity of the standard deviation from the raw output of the network.
#
#
# Let's first define a function that takes as an input the output of the `Z_mean`, and `Z_log_var` previous layer and generate a sample from this input.

# %%
# use reparameterization trick to push the sampling out as input
# note that "output_shape" isn't necessary with the TensorFlow backend

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(batch_size, latent_dim))
    return z_mean + K.exp(z_log_sigma) * epsilon

# %% [markdown]
# Now let's define a keras layer from this function.

# %%
# note that "output_shape" isn't necessary with the TensorFlow backend
# so you could write `Lambda(sampling)([z_mean, z_log_sigma])`
z = kl.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# %% [markdown]
# So far we have defined all the layers we need to build the encoder part of the vae. <br>
# We now define the model, with the `Model`method. For that we just have to specify the input layer and the output we want (here, it's the latent variable z). The model is then build automatically.

# %%
# instantiate encoder model

encoder = km.Model(inputs, z, name='encoder')
encoder.summary()
#ku.plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            1026        dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            1026        dense[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (100, 2)             0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 403,972
# Trainable params: 403,972
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Decoder
#
# The decoder takes as an input the vector z (which is a sample of the latent distribution define by the encoder).
# It is then composed of 2 Dense layers with the following caracteristics :
#
# * 512 neurons, relu activation
# * 784 neurons (input_shape), sigmoid activation
#
# **Exercise** build this simple decoder model using the Model API

# %%
# %load solutions/decoder_vae.py
# build decoder model
latent_inputs = kl.Input(shape=(latent_dim,), name='z_sampling')
x = kl.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = kl.Dense(n_input, activation='sigmoid')(x)

# instantiate decoder model
decoder = km.Model(latent_inputs, outputs, name='decoder')

# %%
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1536
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               402192
# =================================================================
# Total params: 403,728
# Trainable params: 403,728
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Vae
#
# We now associate the encoder and the decoder to define our Variational Autoencoder.
#
# **Exercise** build this VAE model using the Model API

# %%
# %load solutions/vae.py
# instantiate VAE model
outputs = decoder(encoder(inputs))
vae = km.Model(inputs, outputs, name='vae_mlp')
vae.summary()
# Out:
# Model: "vae_mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 784)]             0
# _________________________________________________________________
# encoder (Functional)         (100, 2)                  403972
# _________________________________________________________________
# decoder (Functional)         (None, 784)               403728
# =================================================================
# Total params: 807,700
# Trainable params: 807,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We implement now the vae loss function  as described in the course
#
# $$VAE_{loss} = l(x,\hat{x}) + KL(q(z/x),p(z))$$
#
# $l$ can be any loss function betwen the original image $x$ and the reconstructed image $\hat{x}$. Here we use the binary crossentropy.
#
#
# $$ q(z/x) \sim \mathcal{N}(\mu_z(x), \sigma_z(x)), $$
# as described below. $p(z)$ is the latent distribution. The easiest choice  is  to take $p(z)\sim \mathcal{N}(0,1)$.
#
#
# **We first use the following result, that you can check :**
#
# If $P \sim \mathcal{N}_d(\mu_p, \Sigma_p) $ and $Q \sim \mathcal{N}_d(\mu_q, \Sigma_q) $, then
# $$
# KL(Q || P) = \frac{1}{2}\left[\log\frac{|\Sigma_p|}{|\Sigma_q|} - d + \text{tr} \{ \Sigma_p^{-1}\Sigma_q \} + (\mu_p - \mu_q)^T \Sigma_p^{-1}(\mu_p - \mu_q)\right].
# $$
#
# In our case, $p(z) \sim \mathcal{N}_2(0,  I_2) $ and $ q(z/x) \sim \mathcal{N}_2(\mu_z(x),\sigma_z(x)) $. Hence, we have
#
# $
# KL(q(z/x) || p(z)) = \frac{1}{2}\left[-\log|\sigma_z(x)| - d + \text{tr} \{\sigma_z(x) \} +\mu_z(x)^T \mu_z(x)\right].
# $
#
# which can be computed as :
#
# $KL(q(z/x) || p(z)) = \frac{1}{2} \, \sum_{j=1}^2 \left( \sigma_{z,j}(x) + \mu_{z,j}^2(x) - 1 - \log \sigma_{z,j}(x) \right)$

# %%
reconstruction_loss = kloss.binary_crossentropy(inputs,
                                              outputs)

reconstruction_loss *= 784
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
vae.fit(x_train,
                epochs=40,
                batch_size=batch_size,
                validation_data=(x_test, None))
# Out:
# 2022-10-19 11:07:31.899253: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-10-19 11:07:31.917642: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3199980000 Hz
# Epoch 1/40
# 2022-10-19 11:07:32.301059: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
#  54/600 [=>............................] - ETA: 1s - loss: 384.4554
# 2022-10-19 11:07:32.562043: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 600/600 [==============================] - 4s 5ms/step - loss: 235.6645 - val_loss: 173.5495
# Epoch 2/40
# 600/600 [==============================] - 2s 4ms/step - loss: 170.8976 - val_loss: 165.6239
# Epoch 3/40
# 600/600 [==============================] - 2s 4ms/step - loss: 165.2535 - val_loss: 163.0858
# Epoch 4/40
# 600/600 [==============================] - 2s 4ms/step - loss: 162.9662 - val_loss: 161.6106
# Epoch 5/40
# 600/600 [==============================] - 2s 4ms/step - loss: 160.9024 - val_loss: 160.1878
# Epoch 6/40
# 600/600 [==============================] - 2s 4ms/step - loss: 159.7374 - val_loss: 159.2689
# Epoch 7/40
# 600/600 [==============================] - 2s 4ms/step - loss: 158.5789 - val_loss: 158.1312
# Epoch 8/40
# 600/600 [==============================] - 2s 4ms/step - loss: 157.5928 - val_loss: 157.3032
# Epoch 9/40
# 600/600 [==============================] - 2s 4ms/step - loss: 156.4839 - val_loss: 156.4388
# Epoch 10/40
# 600/600 [==============================] - 2s 4ms/step - loss: 155.7242 - val_loss: 155.5889
# Epoch 11/40
# 600/600 [==============================] - 2s 4ms/step - loss: 154.7581 - val_loss: 155.0433
# Epoch 12/40
# 600/600 [==============================] - 2s 4ms/step - loss: 153.9445 - val_loss: 154.3603
# Epoch 13/40
# 600/600 [==============================] - 2s 4ms/step - loss: 153.4496 - val_loss: 154.0428
# Epoch 14/40
# 600/600 [==============================] - 2s 4ms/step - loss: 152.9457 - val_loss: 153.9143
# Epoch 15/40
# 600/600 [==============================] - 2s 4ms/step - loss: 152.6716 - val_loss: 153.3264
# Epoch 16/40
# 600/600 [==============================] - 2s 4ms/step - loss: 151.6669 - val_loss: 153.0959
# Epoch 17/40
# 600/600 [==============================] - 2s 4ms/step - loss: 151.7203 - val_loss: 152.8167
# Epoch 18/40
# 600/600 [==============================] - 2s 4ms/step - loss: 151.1832 - val_loss: 152.8282
# Epoch 19/40
# 600/600 [==============================] - 2s 4ms/step - loss: 150.9113 - val_loss: 152.2513
# Epoch 20/40
# 600/600 [==============================] - 2s 4ms/step - loss: 150.3439 - val_loss: 151.8989
# Epoch 21/40
# 600/600 [==============================] - 2s 4ms/step - loss: 150.2179 - val_loss: 151.7752
# Epoch 22/40
# 600/600 [==============================] - 2s 4ms/step - loss: 149.8604 - val_loss: 151.5314
# Epoch 23/40
# 600/600 [==============================] - 2s 4ms/step - loss: 149.4158 - val_loss: 151.5091
# Epoch 24/40
# 600/600 [==============================] - 2s 4ms/step - loss: 149.5101 - val_loss: 151.3319
# Epoch 25/40
# 600/600 [==============================] - 2s 4ms/step - loss: 149.1620 - val_loss: 151.3509
# Epoch 26/40
# 600/600 [==============================] - 2s 4ms/step - loss: 148.8989 - val_loss: 150.8889
# Epoch 27/40
# 600/600 [==============================] - 2s 4ms/step - loss: 148.4793 - val_loss: 150.7137
# Epoch 28/40
# 600/600 [==============================] - 2s 4ms/step - loss: 148.4980 - val_loss: 150.6571
# Epoch 29/40
# 600/600 [==============================] - 2s 4ms/step - loss: 148.0872 - val_loss: 150.5765
# Epoch 30/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.8473 - val_loss: 150.4911
# Epoch 31/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.6940 - val_loss: 150.4627
# Epoch 32/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.0266 - val_loss: 150.3497
# Epoch 33/40
# 600/600 [==============================] - 2s 4ms/step - loss: 147.1428 - val_loss: 150.1987
# Epoch 34/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.8812 - val_loss: 150.4644
# Epoch 35/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.7666 - val_loss: 150.0167
# Epoch 36/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.6186 - val_loss: 149.9914
# Epoch 37/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.5757 - val_loss: 149.7284
# Epoch 38/40
# 600/600 [==============================] - 2s 4ms/step - loss: 146.3418 - val_loss: 150.1205
# Epoch 39/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.8837 - val_loss: 149.6393
# Epoch 40/40
# 600/600 [==============================] - 2s 4ms/step - loss: 145.9356 - val_loss: 149.4597

# %% [markdown]
# ### Display images result

# %%
x_test_decoded_vae = vae.predict(x_test, batch_size= batch_size)

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Classification of latent variable

# %%
x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1,1,1)
for i in range(10):
    x_test_encoded_i = x_test_encoded[y_test==i]
    plt.scatter(x_test_encoded_i[:, 0], x_test_encoded_i[:, 1], label=i)
ax.grid(False)
plt.legend()

plt.show()

# %% [markdown]
# ## Generation of number

# %% [markdown]
# ### Single Example

# %% [markdown]
# **Exercise** Generate a image number from two random latent variables using the decoder

# %%
# %load solutions/generate_single_sample.py
z_latents = np.expand_dims(np.random.normal(0,1,2), axis=0)
x_generate = decoder.predict(z_latents)
plt.imshow(x_generate[0].reshape(28, 28))

# %% [markdown]
# ### View of VAE Manifolds

# %%
n = 15  # figure with 15x15 panels
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = sc.stats.norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = sc.stats.norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()

# %% [markdown]
# ## Anomaly Detection
#
# In this part we'll see how variational autoencoder can be used to anomaly detections.
#
# We will consider that 9 images are outliers.
#
# We will generate four datasets from both train and test dataset, train and test without 9 images and train and test with only 9 images.

# %%
outlier_i = 9
x_train_normal = x_train[y_train!=outlier_i]
n_train = x_train_normal.shape[0]-x_train_normal.shape[0]%100
x_train_normal = x_train_normal[:n_train]
x_test_normal =  x_test[y_test!=outlier_i]
n_test = x_test_normal.shape[0]-x_test_normal.shape[0]%100
x_test_normal = x_test_normal[:n_test]

x_train_outliers = x_train[y_train==outlier_i]
n_train = x_train_outliers.shape[0]-x_train_outliers.shape[0]%100
x_train_outliers = x_train_outliers[:n_train]
x_test_outliers =  x_test[y_test==outlier_i]
n_test = x_test_outliers.shape[0]-x_test_outliers.shape[0]%100
x_test_outliers = x_test_outliers[:n_test]

x_train_normal.shape, x_train_outliers.shape, x_test_normal.shape, x_test_outliers.shape
# Out:
# ((54000, 784), (5900, 784), (8900, 784), (1000, 784))

# %% [markdown]
# **Exervise** Build a VAE as we did above on this notebook and learn weights only on train dataset without 9 images.

# %%
# %load solutions/train_outlier_vae.py
# encoder
inputs = kl.Input(shape=(784,), name='encoder_input')
x = kl.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = kl.Dense(latent_dim, name='z_mean')(x)
z_log_var = kl.Dense(latent_dim, name='z_log_var')(x)
z = kl.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])
encoder_ad = km.Model(inputs, z, name='encoder')

# decoder
latent_inputs = kl.Input(shape=(latent_dim,), name='z_sampling')
x = kl.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = kl.Dense(784, activation='sigmoid')(x)
decoder_ad = km.Model(latent_inputs, outputs, name='decoder')

# vae
outputs = decoder_ad(encoder_ad(inputs))
vae_ad = km.Model(inputs, outputs, name='vae_mlp')

reconstruction_loss = kloss.binary_crossentropy(inputs,outputs)
reconstruction_loss *= 784
kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae_ad.add_loss(vae_loss)
vae_ad.compile(optimizer='adam')

vae_ad.fit(x_train_normal,epochs=epochs, batch_size=batch_size, validation_data=(x_test_normal, None))
# Out:
# Epoch 1/25
# 540/540 [==============================] - 3s 4ms/step - loss: 239.9116 - val_loss: 179.0949
# Epoch 2/25
# 540/540 [==============================] - 2s 4ms/step - loss: 176.2539 - val_loss: 170.9706
# Epoch 3/25
# 540/540 [==============================] - 2s 4ms/step - loss: 169.8779 - val_loss: 167.0527
# Epoch 4/25
# 540/540 [==============================] - 2s 4ms/step - loss: 166.3263 - val_loss: 163.8521
# Epoch 5/25
# 540/540 [==============================] - 2s 4ms/step - loss: 163.6231 - val_loss: 161.8882
# Epoch 6/25
# 540/540 [==============================] - 2s 4ms/step - loss: 161.4247 - val_loss: 160.1957
# Epoch 7/25
# 540/540 [==============================] - 2s 4ms/step - loss: 160.1347 - val_loss: 159.1189
# Epoch 8/25
# 540/540 [==============================] - 2s 4ms/step - loss: 159.0721 - val_loss: 158.2387
# Epoch 9/25
# 540/540 [==============================] - 2s 4ms/step - loss: 157.8906 - val_loss: 157.2206
# Epoch 10/25
# 540/540 [==============================] - 2s 4ms/step - loss: 157.0154 - val_loss: 156.6150
# Epoch 11/25
# 540/540 [==============================] - 2s 4ms/step - loss: 155.8509 - val_loss: 156.0359
# Epoch 12/25
# 540/540 [==============================] - 2s 4ms/step - loss: 155.3458 - val_loss: 155.4157
# Epoch 13/25
# 540/540 [==============================] - 2s 4ms/step - loss: 154.7971 - val_loss: 155.1668
# Epoch 14/25
# 540/540 [==============================] - 2s 4ms/step - loss: 154.1144 - val_loss: 154.7075
# Epoch 15/25
# 540/540 [==============================] - 2s 4ms/step - loss: 153.4023 - val_loss: 154.2046
# Epoch 16/25
# 540/540 [==============================] - 2s 4ms/step - loss: 152.8034 - val_loss: 154.2734
# Epoch 17/25
# 540/540 [==============================] - 2s 4ms/step - loss: 152.6274 - val_loss: 153.7372
# Epoch 18/25
# 540/540 [==============================] - 2s 4ms/step - loss: 151.8719 - val_loss: 153.4330
# Epoch 19/25
# 540/540 [==============================] - 2s 4ms/step - loss: 151.6587 - val_loss: 153.4639
# Epoch 20/25
# 540/540 [==============================] - 2s 4ms/step - loss: 151.3904 - val_loss: 152.9536
# Epoch 21/25
# 540/540 [==============================] - 2s 4ms/step - loss: 150.8840 - val_loss: 152.6532
# Epoch 22/25
# 540/540 [==============================] - 2s 4ms/step - loss: 150.7089 - val_loss: 152.5966
# Epoch 23/25
# 540/540 [==============================] - 2s 4ms/step - loss: 150.5270 - val_loss: 152.3795
# Epoch 24/25
# 540/540 [==============================] - 2s 4ms/step - loss: 149.9699 - val_loss: 152.3386
# Epoch 25/25
# 540/540 [==============================] - 2s 4ms/step - loss: 149.6554 - val_loss: 152.0428

# %% [markdown]
# ### Display decoded image
#
# Let's now try to use our VAE on test dataset with both known numbers (0 to 8) and with outliers (9)

# %% [markdown]
# #### Normal Dataset

# %%
x_test_decoded_vae = vae_ad.predict(x_test_normal, batch_size=batch_size)

# %%
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test_normal[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# #### Outlier Dataset

# %%
x_test_decoded_vae = vae_ad.predict(x_test_outliers, batch_size=batch_size)
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_outliers[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    

    # display reconstruction
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_decoded_vae[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# **Question** : What can you say about the decoded images in both cases? Is it normal?

# %% [markdown]
# ### Error Distribution
#
# To evaluate how the detection of 9 images will work, let us check the distribution of the different l2 errors between the original image and their reconstructed image for three types if images:
#
# * Images of know number (0 to 8)
# * Images of outlier (9)
# * Completly randomly generated images
#
# **Exercise** Generate these distributions

# %%
# %load solutions/error_distribution.py
x_test_normal_decoded = vae_ad.predict(x_test_normal, batch_size=batch_size)
error_normal = np.linalg.norm(x_test_normal-x_test_normal_decoded, axis=1)

x_test_outliers_decoded = vae_ad.predict(x_test_outliers, batch_size =batch_size)
error_outliers = np.linalg.norm(x_test_outliers-x_test_outliers_decoded, axis=1)

x_random = np.random.uniform(size=(1000, 784),low=0.0, high=1.0)
x_random_decoded =  vae_ad.predict(x_random, batch_size=batch_size)
error_random = np.linalg.norm(x_random-x_random_decoded, axis=1)

# %%
fig=plt.figure(figsize=(9,5))
ax = fig.add_subplot(1,1,1)
sb.distplot(error_normal, ax=ax, label="Normal")
sb.distplot(error_outliers, ax=ax, label="Outliers")
sb.distplot(error_random , ax=ax, label="Random")

plt.legend()
# Out:
# /usr/local/insa/anaconda/envs/IA-GPU/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/insa/anaconda/envs/IA-GPU/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/insa/anaconda/envs/IA-GPU/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Question** What can you say about the error reconstruction of the different cases? What does it say about the performance of VAE to detect anomalies ?

# %% [markdown]
# ## Convolutional Network
#
# **Exercise** You've seen how to build VAE and how to use it to generate new images and to detect anomalies. The VAE used so far only use Dense layer.
#
# Use CNN layers to build a convolutional VAE and test the different applications (generate images and detect anomalies)
